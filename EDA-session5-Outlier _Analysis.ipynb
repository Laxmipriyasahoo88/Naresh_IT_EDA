# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=r"C:\Users\LISHI\OneDrive\Documents\Datafile\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
plt.boxplot(visa_df['prevailing_wage'])
plt.show()

# %%
q1=np.percentile(visa_df['prevailing_wage'],25)
q1
# Out:
# 34015.479999999996

# %%
q2=np.percentile(visa_df['prevailing_wage'],50)
q2
# Out:
# 70308.20999999999

# %%
q3=np.percentile(visa_df['prevailing_wage'],75)
q3
# Out:
# 107735.51250000001

# %%
#IQR
IQR=q3-q1
IQR
# Out:
# 73720.03250000002

# %%
#calculate the lower and upper bound
lb=q1-1.5*IQR
ub=q3+1.5*IQR
lb,ub
# Out:
# (-76564.56875000002, 218315.56125000003)

# %%
#find outlier
c1=visa_df['prevailing_wage']<lb
c2=visa_df['prevailing_wage']>ub
c=c1 | c2
outlier_df=visa_df[c]
outlier_df
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 14        EZYV15           Asia              Master's                  Y
# 34        EZYV35           Asia              Master's                  N
# 130      EZYV131  South America           High School                  N
# 216      EZYV217           Asia              Master's                  Y
# 221      EZYV222  North America             Doctorate                  Y
# ...          ...            ...                   ...                ...
# 25191  EZYV25192           Asia              Master's                  N
# 25195  EZYV25196  North America              Master's                  Y
# 25468  EZYV25469           Asia            Bachelor's                  N
# 25469  EZYV25470  North America              Master's                  Y
# 25476  EZYV25477           Asia           High School                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
#nonoutliers
c1=visa_df['prevailing_wage']>lb
c2=visa_df['prevailing_wage']<ub
c=c1 & c2
non_outlier_df=visa_df[c]
non_outlier_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
#compare original datt awith non outlier
plt.hist(visa_df['prevailing_wage'])
plt.hist(non_outlier_df['prevailing_wage'])
plt.show()

# %%
#boxplot
plt.boxplot(visa_df['prevailing_wage'])
plt.boxplot(non_outlier_df['prevailing_wage'])
plt.show()

# %%
plt.figure
plt.subplot(2,2,1)
plt.hist(visa_df['prevailing_wage'],bins=40)
plt.subplot(2,2,2)
plt.boxplot(visa_df['prevailing_wage'])
plt.subplot(2,2,3)
plt.hist(non_outlier_df['prevailing_wage'],bins=40)
plt.subplot(2,2,4)
plt.boxplot(non_outlier_df['prevailing_wage'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1552bfe6aa0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1552bfe6ec0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1552bfe6800>],
#  'medians': [<matplotlib.lines.Line2D at 0x1552bfe7400>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1552bfe76a0>],
#  'means': []}

# %%
#another way to compare 
plt.subplot(2,2,1).hist(visa_df['prevailing_wage'],bins=40)
plt.subplot(2,2,2).boxplot(visa_df['prevailing_wage'])
plt.subplot(2,2,3).hist(non_outlier_df['prevailing_wage'],bins=40)
plt.subplot(2,2,4).boxplot(non_outlier_df['prevailing_wage'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1552c2467d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1552c246d10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1552c246650>],
#  'medians': [<matplotlib.lines.Line2D at 0x1552c247250>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1552c2474f0>],
#  'means': []}

# %%
#task1:
#create dataframe
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
frequency_list=[]
for index in range(len(i)-1):
    lower=i[index]
    upper=i[index+1]
    c1=(visa_df['prevailing_wage']>=lower)
    c2=(visa_df['prevailing_wage']<upper)
    freq=len(visa_df[c1&c2])
    frequency_list.append({'lower':lower,'upper':upper,'frequency':freq})
d1=pd.DataFrame(frequency_list)
d1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[82], line 8
#       6 import seaborn as sns
#       7 frequency_list=[]
# ----> 8 for index in range(len(i)-1):
#       9     lower=i[index]
#      10     upper=i[index+1]
#
# TypeError: object of type 'int' has no len()

# %%
l1_lb=[]
l2_ub=[]
l3_f=[]
for i in range(len(n)):
    l1_lb.append(i[index])
    l2_ub.append(i[index+1])
    l3_f.append(f[index])
pd.DataFrame(zip(l1_lb,l2_ub,l3_f),columns=['lower_bound','upper_bound','frequency'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[91], line 5
#       3 l3_f=[]
#       4 for i in range(len(n)):
# ----> 5     l1_lb.append(i[index])
#       6     l2_ub.append(i[index+1])
#       7     l3_f.append(f[index])
#
# TypeError: 'int' object is not subscriptable

# %%
l=i[:40]
p=i[1:41]
lower=[]
upper=[]
freq=[]
for i in l:
    lower.append(i)
for i in p:
    upper.append(i)
for i in freq:
    freq.append(i)
cols=('lower','upper','frequency')
df=pd.DataFrame(zip(lower,upper,frequency),columns=cols)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 l=i[:40]
#       2 p=i[1:41]
#       3 lower=[]
#
# TypeError: 'int' object is not subscriptable

# %%
#Task2
sns.histplot(data=visa_df['prevailing_wage'],bins=40)
# Out:
# <Axes: xlabel='prevailing_wage', ylabel='Count'>

# %%
#task 3
lb=q1-1.5*IQR
ub=q3+1.5*IQR
list1=[]
median=visa_df['prevailing_wage'].median()
for i in visa_df['prevailing_wage']:
    if i<lb or i>ub:
        list1.append(median)
    else:
        list1.append(i)
len(list1)
# Out:
# 25480

# %%
#replce the prvailing wage value with prevailge wage new
lb=q1-1.5*IQR
ub=q3+1.5*IQR
list1=[]
median=visa_df['prevailing_wage'].median()
for i in visa_df['prevailing_wage']:
    if i<lb or i>ub:
        list1.append(median)
    else:
        list1.append(i)
visa_df['prevailing_wage_new']=list1

# %%
plt.boxplot(visa_df['prevailing_wage_new'])
plt.show()

# %%
#read the data again
path=r"C:\Users\LISHI\OneDrive\Documents\Datafile\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
#craete adatafram
dict1={'Name':['A','B','C','D'],'Num':[1,2,3,4]}
d1=pd.DataFrame(dict1)
d1
# Out:
#   Name  Num
# 0    A    1
# 1    B    2
# 2    C    3
# 3    D    4

# %%
dict1={'Name':['A','B','C','D'],'Num':[1,2,3,4]}
d1=pd.DataFrame(dict1)
d1
l=[]
for i in d1['Num']:
    if i >2:
        l.append(100)
    else:
        l.append(i)
d1['Num']=l
d1
# Out:
#   Name  Num
# 0    A    1
# 1    B    2
# 2    C  100
# 3    D  100

# %%
l=np.where(d1['Num']>2,100,d1['Num'])
d1['Num']=l
d1
# Out:
#   Name  Num
# 0    A    1
# 1    B    2
# 2    C  100
# 3    D  100

# %%
#median
lb=q1-1.5*IQR
ub=q3+1.5*IQR
median=visa_df['prevailing_wage'].median()
c1=visa_df['prevailing_wage']<lb
c2=visa_df['prevailing_wage']>ub
con=c1|c2
t=median
f=visa_df['prevailing_wage']
